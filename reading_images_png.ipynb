# %% [markdown]
# ### Baixando a biblioteca OpenCv

# %%
# !pip install opencv-python
import numpy

# %%
#importando a biblioteca

import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Imagens para teste/gato2.jpeg')
plt.imshow(img, 'Imagem original')
plt.show()

# %% [markdown]
# #### Convertendo para escala gray scale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
img_gray
# Out:
# array([[131, 131, 132, ..., 139, 140, 140],
#        [133, 134, 134, ..., 139, 141, 141],
#        [137, 137, 138, ..., 140, 142, 142],
#        ...,
#        [ 62,  65,  70, ..., 109,  96,  96],
#        [ 62,  65,  69, ..., 108, 104, 104],
#        [ 63,  65,  68, ..., 103, 103, 103]], dtype=uint8)

# %% [markdown]
# - Outra forma de lermos images é utilizando a biblioteca PIL
